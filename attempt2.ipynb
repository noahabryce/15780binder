# %%
# !pip install pandas

# %%
# !pip install tqdm

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import trange, tqdm

# %%
df2022 = pd.read_csv('fy2022pa-4.csv')
df2021 = pd.read_csv("data2021-full.csv")
df2020 = pd.read_csv("data2020-full.csv")
df2019 = pd.read_csv("fy19fullpropassess.csv")
df2018 = pd.read_csv('ast2018full.csv')
df2017 = pd.read_csv("property-assessment-fy2017.csv")
df2016 = pd.read_csv("property-assessment-fy2016.csv")
df2015 = pd.read_csv("property-assessment-fy2015.csv")
df2014 = pd.read_csv("property-assessment-fy2014.csv")
df2013 = pd.read_csv("property-assessment-fy13.csv")
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (6,15,27,28,29,34,35,36,37,38,39,40,41,42,44,45,46,47,48,58,59,64,65,66,67,68,69,70,72,73,74) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (15,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (15,60,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
df2017['PID'] = df2017['PID'].str[0:-1]
df2016['PID'] = df2016['PID'].str[0:-1]
df2015['PID'] = df2015['PID'].str[0:-1]
df2014['Parcel_ID'] = df2014['Parcel_ID'].str[0:-1]
df2017['PID'] = df2017['PID'].astype(int)
df2016['PID'] = df2016['PID'].astype(int)
df2015['PID'] = df2015['PID'].astype(int)
df2014['Parcel_ID'] = df2014['Parcel_ID'].astype(int)

# %%
print(len(df2022['PID']))
print(len(df2021['PID']))
print(len(df2020['PID']))
print(len(df2019['PID']))
print(len(df2018['PID']))
print(len(df2017['PID']))
print(len(df2016['PID']))
print(len(df2015['PID']))
print(len(df2014['Parcel_ID']))
'''nt(df2013['PID'])
print(df2022['PID'])
print(df2021['PID'])
print(df2020['PID'])
print(df2019['PID'])
print(df2018['PID'])
print(df2017['PID'])
print(df2016['PID'])
print(df2015['PID'])
print(df2014['Parcel_ID'])
print(df2013['PID'])'''
# Out:
# 178598
# 177091
# 175052
# 174668
# 172841
# 170910
# 169199
# 168115
# 164091
# "nt(df2013['PID'])\nprint(df2022['PID'])\nprint(df2021['PID'])\nprint(df2020['PID'])\nprint(df2019['PID'])\nprint(df2018['PID'])\nprint(df2017['PID'])\nprint(df2016['PID'])\nprint(df2015['PID'])\nprint(df2014['Parcel_ID'])\nprint(df2013['PID'])"

# %%
Pid = set(list(df2022.PID) + list(df2021.PID) + list(df2020.PID) + list(df2019.PID)+ list(df2018.PID) + list(df2017.PID) + list(df2016.PID) + list(df2015.PID)+ list(df2014.Parcel_ID) + list(df2013.PID))
id22 = set(list(df2022.PID))
id21 = set(list(df2021.PID))
id20 = set(list(df2020.PID))
id19 = set(list(df2019.PID))
id18 = set(list(df2018.PID))
id17 = set(list(df2017.PID))
id16 = set(list(df2016.PID))
id15 = set(list(df2015.PID))
id14 = set(list(df2014.Parcel_ID))
id13 = set(list(df2013.PID))
overlap = (id22 & id21 & id20 & id19 & id18 & id17 & id16 & id15 & id14 & id13)
noverlap = Pid - overlap
df2022f = df2022[~df2022['PID'].isin(noverlap)]

# %%
df2022f['val21'] = np.nan
df2022f['val20'] = np.nan
df2022f['val19'] = np.nan
df2022f['val18'] = np.nan
df2022f['val17'] = np.nan
df2022f['val16'] = np.nan
df2022f['val15'] = np.nan
df2022f['val14'] = np.nan
df2022f['val13'] = np.nan
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
for i in tqdm(overlap):
    df2022f.loc[df2022f['PID'] == i, 'val21'] = df2021.loc[df2021['PID'] == i, 'TOTAL_VALUE']
df2021 = 0
df2022f.head
# Out:
#   0%|          | 0/160241 [00:00<?, ?it/s]
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# <bound method NDFrame.head of                PID CM_ID        GIS_ID      ST_NUM          ST_NAME UNIT_NUM  \
# 0        100001000        1.000010e+08  104 A 104         PUTNAM ST      NaN
# 1        100002000        1.000020e+08       197       LEXINGTON ST      NaN
# 2        100003000        1.000030e+08       199       LEXINGTON ST      NaN
# 3        100004000        1.000040e+08       201       LEXINGTON ST      NaN
# 4        100005000        1.000050e+08       203       LEXINGTON ST      NaN
# ...

# %%
for i in tqdm(overlap):
    df2022f.loc[df2022f['PID'] == i, 'val20'] = df2020.loc[df2020['PID'] == i, 'AV_TOTAL']
df2020 = 0
df2022f.head
# Out:
#   0%|          | 0/160241 [00:00<?, ?it/s]
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# <bound method NDFrame.head of                PID CM_ID        GIS_ID      ST_NUM          ST_NAME UNIT_NUM  \
# 0        100001000        1.000010e+08  104 A 104         PUTNAM ST      NaN
# 1        100002000        1.000020e+08       197       LEXINGTON ST      NaN
# 2        100003000        1.000030e+08       199       LEXINGTON ST      NaN
# 3        100004000        1.000040e+08       201       LEXINGTON ST      NaN
# 4        100005000        1.000050e+08       203       LEXINGTON ST      NaN
# ...

# %%
for i in tqdm(overlap):
    df2022f.loc[df2022f['PID'] == i, 'val19'] = df2019.loc[df2019['PID'] == i, 'AV_TOTAL']
    df2022f.loc[df2022f['PID'] == i, 'val18'] = df2018.loc[df2018['PID'] == i, 'AV_TOTAL']
    df2022f.loc[df2022f['PID'] == i, 'val17'] = df2017.loc[df2017['PID'] == i, 'AV_TOTAL']
    df2022f.loc[df2022f['PID'] == i, 'val16'] = df2016.loc[df2016['PID'] == i, 'AV_TOTAL']
    df2022f.loc[df2022f['PID'] == i, 'val15'] = df2015.loc[df2015['PID'] == i, 'AV_TOTAL']
    df2022f.loc[df2022f['PID'] == i, 'val14'] = df2014.loc[df2014['Parcel_ID'] == i, 'AV_TOTAL']
    df2022f.loc[df2022f['PID'] == i, 'val13'] = df2013.loc[df2013['PID'] == i, 'AV_TOTAL']
df2019 = 0
df2018 = 0
df2017 = 0
df2016 = 0
df2015 = 0
df2014 = 0
df2013 = 0
df2022f.head
# Out:
#   0%|          | 0/160241 [00:00<?, ?it/s]
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_135/321375733.py in <module>
#       1 for i in tqdm(overlap):
# ----> 2     df2022f.loc[df2022f['PID'] == i, 'val19'] = df2019.loc[df2019['PID'] == i, 'AV_TOTAL']
#       3     df2022f.loc[df2022f['PID'] == i, 'val18'] = df2018.loc[df2018['PID'] == i, 'AV_TOTAL']
# ...
