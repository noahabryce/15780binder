# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 43.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 33.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2022.4)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.21.6 pandas-1.3.5

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: tqdm
# Successfully installed tqdm-4.64.1

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import trange, tqdm

# %%
df2022 = pd.read_csv('fy2022pa-4.csv')
df2021 = pd.read_csv("data2021-full.csv")
df2020 = pd.read_csv("data2020-full.csv")
df2019 = pd.read_csv("fy19fullpropassess.csv")
df2018 = pd.read_csv('ast2018full.csv')
df2017 = pd.read_csv("property-assessment-fy2017.csv")
df2016 = pd.read_csv("property-assessment-fy2016.csv")
df2015 = pd.read_csv("property-assessment-fy2015.csv")
df2014 = pd.read_csv("property-assessment-fy2014.csv")
df2013 = pd.read_csv("property-assessment-fy13.csv")
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (6,15,27,28,29,34,35,36,37,38,39,40,41,42,44,45,46,47,48,58,59,64,65,66,67,68,69,70,72,73,74) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (15,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (15,60,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (60,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (15,46,53,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (13,46,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
'''print(len(df2022.columns))
print(len(df2021.columns))
print(len(df2020.columns))
print(len(df2019.columns))
print(len(df2018.columns))
print(len(df2017.columns))
print(len(df2016.columns))
print(len(df2015.columns))
print(len(df2014.columns))
print(len(df2013.columns))
print(df2022.columns)
print(df2021.columns)
print(df2020.columns)'''
#print(df2019.columns)
#print(df2018.columns)
print(df2017.PID)
print(df2016.PID)
#print(df2015.columns)
print(df2014.Parcel_ID)
print(df2013.PID)
# Out:
# 0         0100001000_
# 1         0100002000_
# 2         0100003000_
# 3         0100004000_
# 4         0100005000_
#              ...
# 170905    2205668000_
# 170906    2205669000_
# 170907    2205670000_
# 170908    2205670000_
# 170909    2205670000_
# Name: PID, Length: 170910, dtype: object
# 0         1102128015_
# 1         1702569001_
# 2         1800079000_
# 3         1801014000_
# 4         1802070000_
#              ...
# 169194    0903825000_
# 169195    0903880010_
# 169196    0903880010_
# 169197    0903880050_
# 169198    0903882010_
# Name: PID, Length: 169199, dtype: object
# 0         2205670000_
# 1         2205669000_
# 2         2205668000_
# 3         2205667000_
# 4         2205666000_
#              ...
# 164086    0100005000_
# 164087    0100004000_
# 164088    0100003000_
# 164089    0100002000_
# 164090    0100001000_
# Name: Parcel_ID, Length: 164091, dtype: object
# 0          100001000
# 1          100002000
# 2          100003000
# 3          100004000
# 4          100005000
#              ...
# 165603    2205668000
# 165604    2205669000
# 165605    2205670000
# 165606    2205670000
# 165607    2205670000
# Name: PID, Length: 165608, dtype: int64

# %%
Pid = list(set(list(df2022.PID) + list(df2021.PID) + list(df2020.PID) + list(df2019.PID)))
Pid.sort()
id22 = set(list(df2022.PID))
id21 = set(list(df2021.PID))
id20 = set(list(df2020.PID))
id19 = set(list(df2019.PID))
id18 = set(list(df2018.PID))
id17 = set(list(df2017.PID))
id16 = set(list(df2016.PID))
id15 = set(list(df2015.PID))
id14 = set(list(df2014.Parcel_ID))
id13 = set(list(df2013.PID))
c22 = 0
c21 = 0
c20 = 0
c19 = 0
c18 = 0
c17 = 0
c16 = 0
c15 = 0
c14 = 0
c13 = 0
dfval = pd.DataFrame({'2022': np.nan, '2021': np.nan, '2020': np.nan, '2019': np.nan,'2018': np.nan, '2017': np.nan, '2016': np.nan, '2015': np.nan,'2014': np.nan, '2013': np.nan},index = Pid)
for i in trange(len(Pid)):
    if Pid[i] in id22:
        dfval.loc[Pid[i],'2022'] = df2022.loc[i-c22, 'TOTAL_VALUE'] 
    else:
        c22+=1
    if Pid[i] in id21:
        dfval.loc[Pid[i],'2021'] = df2021.loc[i-c21, 'TOTAL_VALUE'] 
    else:
        c21+=1
    if Pid[i] in id20:
        dfval.loc[Pid[i],'2020'] = df2020.loc[i-c20, 'AV_TOTAL'] 
    else:
        c20+=1
    if Pid[i] in id19:
        dfval.loc[Pid[i],'2019'] = df2019.loc[i-c19, 'AV_TOTAL'] 
    else:
        c19+=1
    if Pid[i] in id18:
        dfval.loc[Pid[i],'2018'] = df2018.loc[i-c18, 'AV_TOTAL'] 
    else:
        c18+=1
    if Pid[i] in id17:
        dfval.loc[Pid[i],'2017'] = df2017.loc[i-c17, 'AV_TOTAL'] 
    else:
        c17+=1
    if Pid[i] in id16:
        dfval.loc[Pid[i],'2016'] = df2016.loc[i-c16, 'AV_TOTAL'] 
    else:
        c16+=1
    if Pid[i] in id14:
        dfval.loc[Pid[i],'2014'] = df2014.loc[i-c14, 'AV_TOTAL'] 
    else:
        c14+=1
    if Pid[i] in id13:
        dfval.loc[Pid[i],'2013'] = df2013.loc[i-c13, 'AV_TOTAL'] 
    else:
        c13+=1 
    if Pid[i] in id13:
        dfval.loc[Pid[i],'2013'] = df2013.loc[i-c13, 'AV_TOTAL'] 
    else:
        c13+=1
# Out:
#   0%|          | 0/179137 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_59/1225834041.py in <module>
#      24 for i in trange(len(Pid)):
#      25     if Pid[i] in id22:
# ---> 26         dfval.loc[Pid[i],'2022'] = df2022.loc[i-c22, 'TOTAL_VALUE']
#      27     else:
#      28         c22+=1
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1728         if take_split_path:
#    1729             # We have to operate column-wise
# -> 1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
#    1732             self._setitem_single_block(indexer, value, name)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1815             # scalar value
#    1816             for loc in ilocs:
# -> 1817                 self._setitem_single_column(loc, value, pi)
#    1818
#    1819     def _setitem_with_indexer_2d_value(self, indexer, value):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    1917         else:
#    1918             # set the item, possibly having a dtype change
# -> 1919             ser = ser.copy()
#    1920             ser._mgr = ser._mgr.setitem(indexer=(pi,), value=value)
#    1921             ser._maybe_update_cacher(clear=True)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/generic.py in copy(self, deep)
#    5931         dtype: object
#    5932         """
# -> 5933         data = self._mgr.copy(deep=deep)
#    5934         self._clear_item_cache()
#    5935         return self._constructor(data).__finalize__(self, method="copy")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/internals/managers.py in copy(self, deep)
#     593                 return ax.copy(deep=True) if deep == "all" else ax.view()
#     594
# --> 595             new_axes = [copy_func(ax) for ax in self.axes]
#     596         else:
#     597             new_axes = list(self.axes)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     593                 return ax.copy(deep=True) if deep == "all" else ax.view()
#     594
# --> 595             new_axes = [copy_func(ax) for ax in self.axes]
#     596         else:
#     597             new_axes = list(self.axes)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/internals/managers.py in copy_func(ax)
#     591
#     592             def copy_func(ax):
# --> 593                 return ax.copy(deep=True) if deep == "all" else ax.view()
#     594
#     595             new_axes = [copy_func(ax) for ax in self.axes]
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in view(self, cls)
#     870             result = self._data.view(cls)
#     871         else:
# --> 872             result = self._view()
#     873         if isinstance(result, Index):
#     874             result._id = self._id
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in _view(self)
#     709         fastpath to make a shallow copy, i.e. new object with same data.
#     710         """
# --> 711         result = self._simple_new(self._values, name=self._name)
#     712
#     713         result._cache = self._cache
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in _simple_new(cls, values, name)
#     603         return None
#     604
# --> 605     @classmethod
#     606     def _simple_new(cls: type[_IndexT], values, name: Hashable = None) -> _IndexT:
#     607         """
#
# KeyboardInterrupt:

# %%
dfval.head
# Out:
# <bound method NDFrame.head of                2022          2021      2020       2019      2018  2017  2016  \
# 100001000   719,400  $719,400.00   364700.0   878200.0  483100.0   NaN   NaN
# 100002000   744,800  $744,800.00   373400.0   817600.0  532100.0   NaN   NaN
# 100003000   730,500  $730,500.00   394400.0   849500.0  484300.0   NaN   NaN
# 100004000   667,900  $667,900.00   705700.0   734400.0  462700.0   NaN   NaN
# 100005000   742,700  $714,200.00    38400.0  2162300.0  471900.0   NaN   NaN
# ...             ...           ...       ...        ...       ...   ...   ...
# 2205666000  422,600  $414,300.00        0.0   298500.0  418800.0   NaN   NaN
# 2205667000  422,400  $414,200.00        0.0   249200.0  495500.0   NaN   NaN
# 2205668000  557,900  $571,900.00        0.0   243600.0  554800.0   NaN   NaN
# 2205669000  483,600  $474,200.00        0.0   278500.0  747500.0   NaN   NaN
# 2205670000  480,100  $470,700.00        0.0   311900.0  502500.0   NaN   NaN
#
#             2015  2014      2013
# 100001000    NaN   NaN  230300.0
# 100002000    NaN   NaN  244000.0
# 100003000    NaN   NaN  221000.0
# 100004000    NaN   NaN  218400.0
# 100005000    NaN   NaN  233500.0
# ...          ...   ...       ...
# 2205666000   NaN   NaN  310100.0
# 2205667000   NaN   NaN  517700.0
# 2205668000   NaN   NaN  315900.0
# 2205669000   NaN   NaN  764700.0
# 2205670000   NaN   NaN       0.0
#
# [179137 rows x 10 columns]>

# %%
dfval2 = dfval.dropna()
# Out:
# <bound method NDFrame.head of                2022          2021
# 100001000   719,400  $719,400.00
# 100002000   744,800  $744,800.00
# 100003000   730,500  $730,500.00
# 100004000   667,900  $667,900.00
# 100005000   742,700  $714,200.00
# ...             ...           ...
# 2205666000  422,600  $414,300.00
# 2205667000  422,400  $414,200.00
# 2205668000  557,900  $571,900.00
# 2205669000  483,600  $474,200.00
# 2205670000  480,100  $470,700.00
#
# [178639 rows x 2 columns]>

# %%
ir13 = 1.5 
ir14 = 0.8 
ir15 = 0.7 
ir16 = 2.1 
ir17 = 2.1 
ir18 = 1.9 
ir19 = 2.3 
ir20 = 1.4 
ir21 = 7 
dfif = pd.DataFrame({'2022': np.nan, '2021': np.nan, '2020': np.nan, '2019': np.nan,'2018': np.nan, '2017': np.nan, '2016': np.nan, '2015': np.nan,'2014': np.nan},index = Pid)
